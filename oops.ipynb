# %%
class computer:
    def config(self):
        print("i5, 16gb")

a = '8'

print(type(a))

x = 9

print(type(x))

com1 = computer()

print(type(com1))
# Out:
# <class 'str'>
# <class 'int'>
# <class '__main__.computer'>

# %%
class computer:
    def config(self):
        print("i5, 16gb, 1 TB")
com1 = computer()
computer.config(com1)
# Out:
# i5, 16gb, 1 TB

# %%
class yas:
    def alam(self):
        print("Test, I am netwiork")
        print("python")
net1 = yas()
net2 = yas()
yas.alam(net1)
yas.alam(net2)
# Out:
# Test, I am netwiork
# python
# Test, I am netwiork
# python

# %%
class yas:
    def alam(self):
        print("Test, I am netwiork")
        print("python is best language to learn and easiest to work")
net1 = yas()
net2 = yas()
yas.alam(net1)
yas.alam(net2)
# Out:
# Test, I am netwiork
# python is best language to learn and easiest to work
# Test, I am netwiork
# python is best language to learn and easiest to work

# %%
class yas:
    def alam(self):
        print("Test, I am netwiork")
        print("python is best language to learn and easiest to work")
net1 = yas()
net2 = yas()
yas.alam(net1)
yas.alam(net2)


net1.alam()
net2.alam()
# Out:
# Test, I am netwiork
# python is best language to learn and easiest to work
# Test, I am netwiork
# python is best language to learn and easiest to work
# Test, I am netwiork
# python is best language to learn and easiest to work
# Test, I am netwiork
# python is best language to learn and easiest to work

# %%
class computer:

    def __init__(self):
        print("in init")

    def config(self):
        print("i5, 16gb, 1 TB")
com1 = computer()
com2 = computer()
com1.config()
com2.config()
# Out:
# in init
# in init
# i5, 16gb, 1 TB
# i5, 16gb, 1 TB

# %%
class computer:

    def __init__(self):
        print("in init")

    def config(self):
        print("i5, 16gb, 1 TB")
com1 = computer('i5', 16)
com2 = computer('Ruzwen 3', 8)
com1.config()
com2.config()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 8
#       6     def config(self):
#       7         print("i5, 16gb, 1 TB")
# ----> 8 com1 = computer('i5', 16)
#       9 com2 = computer('Ruzwen 3', 8)
#      10 com1.config()
#
# TypeError: computer.__init__() takes 1 positional argument but 3 were given

# %%
class computer:

    def __init__(self):
        print("in init")

    def config(self):
        print("i5, 16gb, 1 TB")
com1 = computer()
com2 = computer()
com1.config()
com2.config()
# Out:
# in init
# in init
# i5, 16gb, 1 TB
# i5, 16gb, 1 TB

# %%
class computer:

    def __init__(self):
        print("i am an network enginer ")
